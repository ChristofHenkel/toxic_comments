# %%
import re, os, gc, time, pandas as pd, numpy as np
import tqdm

np.random.seed(32)
os.environ["OMP_NUM_THREADS"] = "5"
from nltk import tokenize, word_tokenize
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, GRU, Embedding, Dropout, Activation, Conv1D
from keras.layers import Bidirectional, Add, Flatten, TimeDistributed,CuDNNGRU,CuDNNLSTM
from keras.optimizers import Adam, RMSprop
from keras.models import Model, load_model
from keras import initializers, regularizers, constraints, optimizers, layers
from keras import backend as K
# from keras.engine.topology import Layer
from keras.engine import InputSpec, Layer
from global_variables import TRAIN_FILENAME, TEST_FILENAME, COMMENT, LIST_CLASSES
import logging
from sklearn.metrics import roc_auc_score
from keras.callbacks import Callback


"""
I should also try:
https://github.com/richliao/textClassifier/blob/master/textClassifierHATT.py
"""


class RocAucEvaluation(Callback):
    def __init__(self, validation_data=(), interval=1):
        super(Callback, self).__init__()

        self.interval = interval
        self.X_val, self.y_val = validation_data

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict(self.X_val, verbose=0)
            score = roc_auc_score(self.y_val, y_pred)
            print("\n ROC-AUC - epoch: {:d} - score: {:.6f}".format(epoch + 1, score))


class AttentionWeightedAverage(Layer):
    """
    Computes a weighted average of the different channels across timesteps.
    Uses 1 parameter pr. channel to compute the attention value for a single timestep.
    """

    def __init__(self, return_attention=False, **kwargs):
        self.init = initializers.get('uniform')
        self.supports_masking = True
        self.return_attention = return_attention
        super(AttentionWeightedAverage, self).__init__(**kwargs)

    def build(self, input_shape):
        self.input_spec = [InputSpec(ndim=3)]
        assert len(input_shape) == 3

        self.W = self.add_weight(shape=(input_shape[2], 1),
                                 name='{}_W'.format(self.name),
                                 initializer=self.init)
        self.trainable_weights = [self.W]
        super(AttentionWeightedAverage, self).build(input_shape)

    def call(self, x, mask=None):
        # computes a probability distribution over the timesteps
        # uses 'max trick' for numerical stability
        # reshape is done to avoid issue with Tensorflow
        # and 1-dimensional weights
        logits = K.dot(x, self.W)
        x_shape = K.shape(x)
        logits = K.reshape(logits, (x_shape[0], x_shape[1]))
        ai = K.exp(logits - K.max(logits, axis=-1, keepdims=True))

        # masked timesteps have zero weight
        if mask is not None:
            mask = K.cast(mask, K.floatx())
            ai = ai * mask
        att_weights = ai / (K.sum(ai, axis=1, keepdims=True) + K.epsilon())
        weighted_input = x * K.expand_dims(att_weights)
        result = K.sum(weighted_input, axis=1)
        if self.return_attention:
            return [result, att_weights]
        return result

    def get_output_shape_for(self, input_shape):
        return self.compute_output_shape(input_shape)

    def compute_output_shape(self, input_shape):
        output_len = input_shape[2]
        if self.return_attention:
            return [(input_shape[0], output_len), (input_shape[0], input_shape[1])]
        return (input_shape[0], output_len)

    def compute_mask(self, input, input_mask=None):
        if isinstance(input_mask, list):
            return [None] * len(input_mask)
        else:
            return None


embed_size = 300
max_features = 150000
max_text_len = 300
max_sent = 5

# EMBEDDING_FILE = "../input/glove840b300dtxt/glove.840B.300d.txt
EMBEDDING_FILE = "assets/embedding_models/ft_300d_crawl/crawl-300d-2M.vec"


def clean_corpus(comment):
    comment = comment.replace('&', ' and ')
    comment = comment.replace('0', ' zero ')
    comment = comment.replace('1', ' one ')
    comment = comment.replace('2', ' two ')
    comment = comment.replace('3', ' three ')
    comment = comment.replace('4', ' four ')
    comment = comment.replace('5', ' five ')
    comment = comment.replace('6', ' six ')
    comment = comment.replace('7', ' seven ')
    comment = comment.replace('8', ' eight ')
    comment = comment.replace('9', ' nine ')
    comment = comment.replace('\'ve', ' have ')
    comment = comment.replace('\'d', ' would ')
    comment = comment.replace('\'m', ' am ')
    comment = comment.replace('n\'t', ' not ')
    comment = comment.replace('\'s', ' is ')
    comment = comment.replace('\'r', ' are ')
    comment = re.sub(r"\\", "", comment)
    comment = word_tokenize(comment)
    comment = " ".join(word for word in comment)
    return comment.strip().lower()


tic = time.time()

train = pd.read_csv(TRAIN_FILENAME)
test = pd.read_csv(TEST_FILENAME)
Y = train[LIST_CLASSES].values

print('cleaning corpus')
train[COMMENT].fillna("no comment", inplace = True)
train[COMMENT] = train[COMMENT].apply(lambda x: clean_corpus(x))

test[COMMENT].fillna("no comment", inplace = True)
test[COMMENT] = test[COMMENT].apply(lambda x: clean_corpus(x))

print('tokenizing')
train["sentences"] = train[COMMENT].apply(lambda x: tokenize.sent_tokenize(x))
test["sentences"] = test[COMMENT].apply(lambda x: tokenize.sent_tokenize(x))
toc = time.time()
print(toc-tic)


from keras.preprocessing.text import Tokenizer, text_to_word_sequence

print('fitting tokenizer')
raw_text = train[COMMENT]
tk = Tokenizer(num_words = max_features, lower = True)
tk.fit_on_texts(raw_text)

def sentenize(data):
    comments = data["sentences"]
    sent_matrix = np.zeros((len(comments), max_sent, max_text_len), dtype = "int32")
    for i, sentences in enumerate(comments):
        for j, sent in enumerate(sentences):
            if j < max_sent:
                wordTokens = text_to_word_sequence(sent)
                k=0
                for _, word in enumerate(wordTokens):
                    try:
                        if k < max_text_len and tk.word_index[word] < max_features:
                            sent_matrix[i, j, k] = tk.word_index[word]
                            k = k+1
                    except:
                            sent_matrix[i, j, k] = 0
                            k = k+1
    return sent_matrix

print('sentenizing')
X = sentenize(train)
X_test = sentenize(test)

del train, test
gc.collect()

print('loading embeddings')
tic = time.time()
def get_coefs(word,*arr): return word, np.asarray(arr, dtype = "float32")
embeddings_index = dict(get_coefs(*o.strip().split()) for o in open(EMBEDDING_FILE))

word_index = tk.word_index
nb_words = min(max_features, len(word_index))
embedding_matrix = np.zeros((nb_words, embed_size))
for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector
toc = time.time()
print(toc-tic)
# Out:
# /home/christof/miniconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/christof/miniconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# cleaning corpus
# tokenizing
# 175.55582976341248
# fitting tokenizer
# sentenizing
# loading embeddings
# 85.90108561515808

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import SpatialDropout1D,GlobalAveragePooling1D,GlobalMaxPooling1D,concatenate

def build_model(rnn_units = 0, lr = 0.0):
    sentence_input = Input(shape = (max_text_len,), dtype = "int32")
    embedded_sequences = Embedding(nb_words, embed_size, weights=[embedding_matrix],
              input_length=max_text_len, trainable=False)(sentence_input)
    do_embedded_sequences = SpatialDropout1D(0.5)(embedded_sequences)
    l_lstm = Bidirectional(CuDNNLSTM(rnn_units),merge_mode='sum')(do_embedded_sequences)
    sentEncoder = Model(sentence_input, l_lstm)

    review_input = Input(shape = (max_sent, max_text_len), dtype = "int32")
    review_encoder = TimeDistributed(sentEncoder)(review_input)
    review_encoder = SpatialDropout1D(0.5)(review_encoder)
    l_lstm_sent = Bidirectional(CuDNNLSTM(rnn_units),merge_mode='sum')(review_encoder)
    
    
    #l_lstm_sent = Bidirectional(CuDNNLSTM(rnn_units,return_sequences=True))(review_encoder)
    #avg_pool = GlobalAveragePooling1D()(l_lstm_sent)
    #max_pool = GlobalMaxPooling1D()(l_lstm_sent)
    #conc = concatenate([avg_pool, max_pool])
    #conc = Dropout(0.2)(conc)
    #out = Dense(6, activation="sigmoid")(conc)
    l_lstm_sent = Dropout(0.2)(l_lstm_sent)
    out = Dense(6, activation = "sigmoid")(l_lstm_sent)
    model = Model(review_input, out)
    model.compile(loss = "binary_crossentropy", optimizer = Adam(lr = lr),  metrics = ["accuracy"])
    return model



model = build_model(rnn_units = 32, lr = 1e-3)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 5, 300)            0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 5, 32)             45085504
# _________________________________________________________________
# spatial_dropout1d_2 (Spatial (None, 5, 32)             0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 32)                16896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 45,102,598
# Trainable params: 102,598
# Non-trainable params: 45,000,000
# _________________________________________________________________

# %%
fold_id = 9
fold_size = len(X) // 10
fold_start = fold_size * fold_id
fold_end = fold_start + fold_size

# %%
fold_end
# Out:
# 159571

# %%
if fold_id == 9:
    fold_end = len(X)

# %%
X_valid = X[fold_start:fold_end]
Y_valid = Y[fold_start:fold_end]
X_train = np.concatenate([X[:fold_start], X[fold_end:]])
Y_train = np.concatenate([Y[:fold_start], Y[fold_end:]])

model = build_model(rnn_units = 64, lr = 1e-3)
file_path = "HAN_%s_.hdf5" %fold_id
ra_val = RocAucEvaluation(validation_data = (X_valid, Y_valid), interval = 1)
check_point = ModelCheckpoint(file_path, monitor = "val_loss", mode = "min", save_best_only = True, verbose = 1)
history = model.fit(X_train, Y_train, batch_size = 64, epochs = 15, validation_data = (X_valid, Y_valid),
                verbose = 1, callbacks = [ra_val, check_point])
# Out:
# Train on 143613 samples, validate on 15958 samples
# Epoch 1/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0692 - acc: 0.9769
#  ROC-AUC - epoch: 1 - score: 0.971781
#
# Epoch 00001: val_loss improved from inf to 0.05087, saving model to HAN_9_.hdf5
# 143613/143613 [==============================] - 206s 1ms/step - loss: 0.0692 - acc: 0.9769 - val_loss: 0.0509 - val_acc: 0.9813
# Epoch 2/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0537 - acc: 0.9806
#  ROC-AUC - epoch: 2 - score: 0.978148
#
# Epoch 00002: val_loss improved from 0.05087 to 0.04822, saving model to HAN_9_.hdf5
# 143613/143613 [==============================] - 204s 1ms/step - loss: 0.0537 - acc: 0.9806 - val_loss: 0.0482 - val_acc: 0.9820
# Epoch 3/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0507 - acc: 0.9813
#  ROC-AUC - epoch: 3 - score: 0.979982
#
# Epoch 00003: val_loss did not improve
# 143613/143613 [==============================] - 203s 1ms/step - loss: 0.0507 - acc: 0.9813 - val_loss: 0.0499 - val_acc: 0.9820
# Epoch 4/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0486 - acc: 0.9820
#  ROC-AUC - epoch: 4 - score: 0.982253
#
# Epoch 00004: val_loss improved from 0.04822 to 0.04624, saving model to HAN_9_.hdf5
# 143613/143613 [==============================] - 207s 1ms/step - loss: 0.0486 - acc: 0.9820 - val_loss: 0.0462 - val_acc: 0.9828
# Epoch 5/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0475 - acc: 0.9823
#  ROC-AUC - epoch: 5 - score: 0.983539
#
# Epoch 00005: val_loss improved from 0.04624 to 0.04468, saving model to HAN_9_.hdf5
# 143613/143613 [==============================] - 203s 1ms/step - loss: 0.0475 - acc: 0.9823 - val_loss: 0.0447 - val_acc: 0.9829
# Epoch 6/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0463 - acc: 0.9828
#  ROC-AUC - epoch: 6 - score: 0.984120
#
# Epoch 00006: val_loss improved from 0.04468 to 0.04423, saving model to HAN_9_.hdf5
# 143613/143613 [==============================] - 203s 1ms/step - loss: 0.0463 - acc: 0.9828 - val_loss: 0.0442 - val_acc: 0.9831
# Epoch 7/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0457 - acc: 0.9829
#  ROC-AUC - epoch: 7 - score: 0.984087
#
# Epoch 00007: val_loss did not improve
# 143613/143613 [==============================] - 201s 1ms/step - loss: 0.0457 - acc: 0.9829 - val_loss: 0.0447 - val_acc: 0.9831
# Epoch 8/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0448 - acc: 0.9831
#  ROC-AUC - epoch: 8 - score: 0.984326
#
# Epoch 00008: val_loss improved from 0.04423 to 0.04409, saving model to HAN_9_.hdf5
# 143613/143613 [==============================] - 208s 1ms/step - loss: 0.0448 - acc: 0.9831 - val_loss: 0.0441 - val_acc: 0.9832
# Epoch 9/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0444 - acc: 0.9831
#  ROC-AUC - epoch: 9 - score: 0.985265
#
# Epoch 00009: val_loss did not improve
# 143613/143613 [==============================] - 209s 1ms/step - loss: 0.0444 - acc: 0.9831 - val_loss: 0.0442 - val_acc: 0.9831
# Epoch 10/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0436 - acc: 0.9834
#  ROC-AUC - epoch: 10 - score: 0.985174
#
# Epoch 00010: val_loss did not improve
# 143613/143613 [==============================] - 200s 1ms/step - loss: 0.0436 - acc: 0.9834 - val_loss: 0.0442 - val_acc: 0.9838
# Epoch 11/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0436 - acc: 0.9835
#  ROC-AUC - epoch: 11 - score: 0.985470
#
# Epoch 00011: val_loss improved from 0.04409 to 0.04355, saving model to HAN_9_.hdf5
# 143613/143613 [==============================] - 200s 1ms/step - loss: 0.0436 - acc: 0.9835 - val_loss: 0.0435 - val_acc: 0.9834
# Epoch 12/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0431 - acc: 0.9835
#  ROC-AUC - epoch: 12 - score: 0.985694
#
# Epoch 00012: val_loss did not improve
# 143613/143613 [==============================] - 206s 1ms/step - loss: 0.0431 - acc: 0.9835 - val_loss: 0.0436 - val_acc: 0.9833
# Epoch 13/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0424 - acc: 0.9839
#  ROC-AUC - epoch: 13 - score: 0.985458
#
# Epoch 00013: val_loss did not improve
# 143613/143613 [==============================] - 214s 1ms/step - loss: 0.0424 - acc: 0.9839 - val_loss: 0.0437 - val_acc: 0.9833
# Epoch 14/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0423 - acc: 0.9839
#  ROC-AUC - epoch: 14 - score: 0.985255
#
# Epoch 00014: val_loss did not improve
# 143613/143613 [==============================] - 214s 1ms/step - loss: 0.0423 - acc: 0.9839 - val_loss: 0.0440 - val_acc: 0.9832
# Epoch 15/15
# 143552/143613 [============================>.] - ETA: 0s - loss: 0.0421 - acc: 0.9840
#  ROC-AUC - epoch: 15 - score: 0.986324
#
# Epoch 00015: val_loss did not improve
# 143613/143613 [==============================] - 214s 1ms/step - loss: 0.0421 - acc: 0.9840 - val_loss: 0.0438 - val_acc: 0.9831

# %%
fold_count = 10
fold_size = len(X) // 10
for fold_id in range(0, fold_count):
    fold_start = fold_size * fold_id
    fold_end = fold_start + fold_size

    if fold_id == 9:
        fold_end = len(X)

    X_valid = X[fold_start:fold_end]
    Y_valid = Y[fold_start:fold_end]
    X_train = np.concatenate([X[:fold_start], X[fold_end:]])
    Y_train = np.concatenate([Y[:fold_start], Y[fold_end:]])

    model = build_model(rnn_units = 64, lr = 1e-3)
    file_path = "HAN_%s_.hdf5" %fold_id
    ra_val = RocAucEvaluation(validation_data = (X_valid, Y_valid), interval = 1)
    check_point = ModelCheckpoint(file_path, monitor = "val_loss", mode = "min", save_best_only = True, verbose = 1)
    history = model.fit(X_train, Y_train, batch_size = 64, epochs = 15, validation_data = (X_valid, Y_valid),
                    verbose = 1, callbacks = [ra_val, check_point])
# Out:
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0705 - acc: 0.9768
#  ROC-AUC - epoch: 1 - score: 0.975378
#
# Epoch 00001: val_loss improved from inf to 0.05095, saving model to HAN_0_.hdf5
# 143614/143614 [==============================] - 202s 1ms/step - loss: 0.0705 - acc: 0.9768 - val_loss: 0.0510 - val_acc: 0.9807
# Epoch 2/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0541 - acc: 0.9807
#  ROC-AUC - epoch: 2 - score: 0.979589
#
# Epoch 00002: val_loss improved from 0.05095 to 0.04723, saving model to HAN_0_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0541 - acc: 0.9807 - val_loss: 0.0472 - val_acc: 0.9823
# Epoch 3/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0509 - acc: 0.9814
#  ROC-AUC - epoch: 3 - score: 0.981205
#
# Epoch 00003: val_loss improved from 0.04723 to 0.04577, saving model to HAN_0_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0509 - acc: 0.9814 - val_loss: 0.0458 - val_acc: 0.9825
# Epoch 4/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0490 - acc: 0.9820
#  ROC-AUC - epoch: 4 - score: 0.982592
#
# Epoch 00004: val_loss improved from 0.04577 to 0.04448, saving model to HAN_0_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0490 - acc: 0.9820 - val_loss: 0.0445 - val_acc: 0.9830
# Epoch 5/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0478 - acc: 0.9823
#  ROC-AUC - epoch: 5 - score: 0.983621
#
# Epoch 00005: val_loss improved from 0.04448 to 0.04338, saving model to HAN_0_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0479 - acc: 0.9823 - val_loss: 0.0434 - val_acc: 0.9833
# Epoch 6/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0468 - acc: 0.9824
#  ROC-AUC - epoch: 6 - score: 0.983867
#
# Epoch 00006: val_loss improved from 0.04338 to 0.04325, saving model to HAN_0_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0468 - acc: 0.9824 - val_loss: 0.0432 - val_acc: 0.9833
# Epoch 7/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0459 - acc: 0.9827
#  ROC-AUC - epoch: 7 - score: 0.985115
#
# Epoch 00007: val_loss improved from 0.04325 to 0.04231, saving model to HAN_0_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0459 - acc: 0.9827 - val_loss: 0.0423 - val_acc: 0.9836
# Epoch 8/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0452 - acc: 0.9831
#  ROC-AUC - epoch: 8 - score: 0.985399
#
# Epoch 00008: val_loss improved from 0.04231 to 0.04219, saving model to HAN_0_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0452 - acc: 0.9831 - val_loss: 0.0422 - val_acc: 0.9839
# Epoch 9/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0446 - acc: 0.9832
#  ROC-AUC - epoch: 9 - score: 0.984523
#
# Epoch 00009: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0446 - acc: 0.9832 - val_loss: 0.0423 - val_acc: 0.9839
# Epoch 10/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0441 - acc: 0.9833
#  ROC-AUC - epoch: 10 - score: 0.984624
#
# Epoch 00010: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0441 - acc: 0.9833 - val_loss: 0.0423 - val_acc: 0.9837
# Epoch 11/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0438 - acc: 0.9833
#  ROC-AUC - epoch: 11 - score: 0.985436
#
# Epoch 00011: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0438 - acc: 0.9833 - val_loss: 0.0428 - val_acc: 0.9834
# Epoch 12/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0431 - acc: 0.9836
#  ROC-AUC - epoch: 12 - score: 0.985902
#
# Epoch 00012: val_loss improved from 0.04219 to 0.04171, saving model to HAN_0_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0432 - acc: 0.9836 - val_loss: 0.0417 - val_acc: 0.9837
# Epoch 13/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0429 - acc: 0.9837
#  ROC-AUC - epoch: 13 - score: 0.985580
#
# Epoch 00013: val_loss did not improve
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0429 - acc: 0.9837 - val_loss: 0.0430 - val_acc: 0.9834
# Epoch 14/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0423 - acc: 0.9838
#  ROC-AUC - epoch: 14 - score: 0.985450
#
# Epoch 00014: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0423 - acc: 0.9838 - val_loss: 0.0419 - val_acc: 0.9839
# Epoch 15/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0420 - acc: 0.9840
#  ROC-AUC - epoch: 15 - score: 0.985116
#
# Epoch 00015: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0420 - acc: 0.9840 - val_loss: 0.0428 - val_acc: 0.9834
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0736 - acc: 0.9762
#  ROC-AUC - epoch: 1 - score: 0.973203
#
# Epoch 00001: val_loss improved from inf to 0.05275, saving model to HAN_1_.hdf5
# 143614/143614 [==============================] - 202s 1ms/step - loss: 0.0736 - acc: 0.9762 - val_loss: 0.0527 - val_acc: 0.9802
# Epoch 2/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0545 - acc: 0.9807
#  ROC-AUC - epoch: 2 - score: 0.976237
#
# Epoch 00002: val_loss improved from 0.05275 to 0.05222, saving model to HAN_1_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0545 - acc: 0.9806 - val_loss: 0.0522 - val_acc: 0.9808
# Epoch 3/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0512 - acc: 0.9814
#  ROC-AUC - epoch: 3 - score: 0.979490
#
# Epoch 00003: val_loss improved from 0.05222 to 0.04899, saving model to HAN_1_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0512 - acc: 0.9814 - val_loss: 0.0490 - val_acc: 0.9815
# Epoch 4/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0496 - acc: 0.9817
#  ROC-AUC - epoch: 4 - score: 0.980933
#
# Epoch 00004: val_loss improved from 0.04899 to 0.04750, saving model to HAN_1_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0496 - acc: 0.9817 - val_loss: 0.0475 - val_acc: 0.9816
# Epoch 5/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0482 - acc: 0.9822
#  ROC-AUC - epoch: 5 - score: 0.981289
#
# Epoch 00005: val_loss did not improve
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0482 - acc: 0.9822 - val_loss: 0.0475 - val_acc: 0.9818
# Epoch 6/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0473 - acc: 0.9825
#  ROC-AUC - epoch: 6 - score: 0.982928
#
# Epoch 00006: val_loss improved from 0.04750 to 0.04587, saving model to HAN_1_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0473 - acc: 0.9825 - val_loss: 0.0459 - val_acc: 0.9825
# Epoch 7/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0466 - acc: 0.9827
#  ROC-AUC - epoch: 7 - score: 0.983983
#
# Epoch 00007: val_loss improved from 0.04587 to 0.04523, saving model to HAN_1_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0466 - acc: 0.9827 - val_loss: 0.0452 - val_acc: 0.9827
# Epoch 8/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0456 - acc: 0.9829
#  ROC-AUC - epoch: 8 - score: 0.984400
#
# Epoch 00008: val_loss improved from 0.04523 to 0.04488, saving model to HAN_1_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0456 - acc: 0.9829 - val_loss: 0.0449 - val_acc: 0.9827
# Epoch 9/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0452 - acc: 0.9830
#  ROC-AUC - epoch: 9 - score: 0.984470
#
# Epoch 00009: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0452 - acc: 0.9830 - val_loss: 0.0454 - val_acc: 0.9828
# Epoch 10/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0444 - acc: 0.9832
#  ROC-AUC - epoch: 10 - score: 0.985063
#
# Epoch 00010: val_loss improved from 0.04488 to 0.04479, saving model to HAN_1_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0444 - acc: 0.9832 - val_loss: 0.0448 - val_acc: 0.9828
# Epoch 11/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0440 - acc: 0.9833
#  ROC-AUC - epoch: 11 - score: 0.984898
#
# Epoch 00011: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0440 - acc: 0.9833 - val_loss: 0.0449 - val_acc: 0.9827
# Epoch 12/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0433 - acc: 0.9837
#  ROC-AUC - epoch: 12 - score: 0.985234
#
# Epoch 00012: val_loss improved from 0.04479 to 0.04415, saving model to HAN_1_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0433 - acc: 0.9837 - val_loss: 0.0441 - val_acc: 0.9829
# Epoch 13/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0432 - acc: 0.9837
#  ROC-AUC - epoch: 13 - score: 0.985091
#
# Epoch 00013: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0432 - acc: 0.9837 - val_loss: 0.0449 - val_acc: 0.9830
# Epoch 14/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0428 - acc: 0.9839
#  ROC-AUC - epoch: 14 - score: 0.985821
#
# Epoch 00014: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0428 - acc: 0.9839 - val_loss: 0.0444 - val_acc: 0.9830
# Epoch 15/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0424 - acc: 0.9839
#  ROC-AUC - epoch: 15 - score: 0.985554
#
# Epoch 00015: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0424 - acc: 0.9839 - val_loss: 0.0442 - val_acc: 0.9831
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0739 - acc: 0.9762
#  ROC-AUC - epoch: 1 - score: 0.975469
#
# Epoch 00001: val_loss improved from inf to 0.05059, saving model to HAN_2_.hdf5
# 143614/143614 [==============================] - 202s 1ms/step - loss: 0.0739 - acc: 0.9762 - val_loss: 0.0506 - val_acc: 0.9814
# Epoch 2/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0544 - acc: 0.9806
#  ROC-AUC - epoch: 2 - score: 0.979378
#
# Epoch 00002: val_loss improved from 0.05059 to 0.04902, saving model to HAN_2_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0544 - acc: 0.9806 - val_loss: 0.0490 - val_acc: 0.9818
# Epoch 3/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0511 - acc: 0.9814
#  ROC-AUC - epoch: 3 - score: 0.982565
#
# Epoch 00003: val_loss improved from 0.04902 to 0.04705, saving model to HAN_2_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0512 - acc: 0.9814 - val_loss: 0.0470 - val_acc: 0.9822
# Epoch 4/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0493 - acc: 0.9819
#  ROC-AUC - epoch: 4 - score: 0.984515
#
# Epoch 00004: val_loss improved from 0.04705 to 0.04490, saving model to HAN_2_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0493 - acc: 0.9819 - val_loss: 0.0449 - val_acc: 0.9827
# Epoch 5/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0480 - acc: 0.9822
#  ROC-AUC - epoch: 5 - score: 0.985655
#
# Epoch 00005: val_loss improved from 0.04490 to 0.04466, saving model to HAN_2_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0480 - acc: 0.9822 - val_loss: 0.0447 - val_acc: 0.9828
# Epoch 6/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0469 - acc: 0.9825
#  ROC-AUC - epoch: 6 - score: 0.986457
#
# Epoch 00006: val_loss improved from 0.04466 to 0.04438, saving model to HAN_2_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0469 - acc: 0.9825 - val_loss: 0.0444 - val_acc: 0.9828
# Epoch 7/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0460 - acc: 0.9827
#  ROC-AUC - epoch: 7 - score: 0.987130
#
# Epoch 00007: val_loss improved from 0.04438 to 0.04322, saving model to HAN_2_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0460 - acc: 0.9827 - val_loss: 0.0432 - val_acc: 0.9833
# Epoch 8/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0453 - acc: 0.9829
#  ROC-AUC - epoch: 8 - score: 0.987709
#
# Epoch 00008: val_loss improved from 0.04322 to 0.04317, saving model to HAN_2_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0452 - acc: 0.9829 - val_loss: 0.0432 - val_acc: 0.9834
# Epoch 9/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0448 - acc: 0.9832
#  ROC-AUC - epoch: 9 - score: 0.987484
#
# Epoch 00009: val_loss improved from 0.04317 to 0.04283, saving model to HAN_2_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0448 - acc: 0.9832 - val_loss: 0.0428 - val_acc: 0.9836
# Epoch 10/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0442 - acc: 0.9831
#  ROC-AUC - epoch: 10 - score: 0.987484
#
# Epoch 00010: val_loss improved from 0.04283 to 0.04261, saving model to HAN_2_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0442 - acc: 0.9831 - val_loss: 0.0426 - val_acc: 0.9836
# Epoch 11/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0437 - acc: 0.9835
#  ROC-AUC - epoch: 11 - score: 0.988093
#
# Epoch 00011: val_loss improved from 0.04261 to 0.04234, saving model to HAN_2_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0437 - acc: 0.9835 - val_loss: 0.0423 - val_acc: 0.9838
# Epoch 12/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0435 - acc: 0.9836
#  ROC-AUC - epoch: 12 - score: 0.987881
#
# Epoch 00012: val_loss improved from 0.04234 to 0.04214, saving model to HAN_2_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0435 - acc: 0.9836 - val_loss: 0.0421 - val_acc: 0.9839
# Epoch 13/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0432 - acc: 0.9836
#  ROC-AUC - epoch: 13 - score: 0.987980
#
# Epoch 00013: val_loss did not improve
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0432 - acc: 0.9836 - val_loss: 0.0423 - val_acc: 0.9840
# Epoch 14/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0427 - acc: 0.9837
#  ROC-AUC - epoch: 14 - score: 0.988041
#
# Epoch 00014: val_loss did not improve
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0427 - acc: 0.9837 - val_loss: 0.0429 - val_acc: 0.9834
# Epoch 15/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0425 - acc: 0.9838
#  ROC-AUC - epoch: 15 - score: 0.988093
#
# Epoch 00015: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0425 - acc: 0.9838 - val_loss: 0.0421 - val_acc: 0.9838
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0769 - acc: 0.9756
#  ROC-AUC - epoch: 1 - score: 0.968961
#
# Epoch 00001: val_loss improved from inf to 0.05279, saving model to HAN_3_.hdf5
# 143614/143614 [==============================] - 203s 1ms/step - loss: 0.0768 - acc: 0.9756 - val_loss: 0.0528 - val_acc: 0.9809
# Epoch 2/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0546 - acc: 0.9804
#  ROC-AUC - epoch: 2 - score: 0.972787
#
# Epoch 00002: val_loss improved from 0.05279 to 0.04937, saving model to HAN_3_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0547 - acc: 0.9804 - val_loss: 0.0494 - val_acc: 0.9821
# Epoch 3/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0516 - acc: 0.9812
#  ROC-AUC - epoch: 3 - score: 0.974954
#
# Epoch 00003: val_loss improved from 0.04937 to 0.04859, saving model to HAN_3_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0516 - acc: 0.9812 - val_loss: 0.0486 - val_acc: 0.9824
# Epoch 4/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0499 - acc: 0.9816
#  ROC-AUC - epoch: 4 - score: 0.977234
#
# Epoch 00004: val_loss improved from 0.04859 to 0.04667, saving model to HAN_3_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0499 - acc: 0.9816 - val_loss: 0.0467 - val_acc: 0.9827
# Epoch 5/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0481 - acc: 0.9822
#  ROC-AUC - epoch: 5 - score: 0.978960
#
# Epoch 00005: val_loss improved from 0.04667 to 0.04564, saving model to HAN_3_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0481 - acc: 0.9822 - val_loss: 0.0456 - val_acc: 0.9833
# Epoch 6/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0474 - acc: 0.9824
#  ROC-AUC - epoch: 6 - score: 0.978599
#
# Epoch 00006: val_loss improved from 0.04564 to 0.04541, saving model to HAN_3_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0474 - acc: 0.9824 - val_loss: 0.0454 - val_acc: 0.9834
# Epoch 7/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0462 - acc: 0.9827
#  ROC-AUC - epoch: 7 - score: 0.980398
#
# Epoch 00007: val_loss improved from 0.04541 to 0.04501, saving model to HAN_3_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0462 - acc: 0.9827 - val_loss: 0.0450 - val_acc: 0.9834
# Epoch 8/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0454 - acc: 0.9830
#  ROC-AUC - epoch: 8 - score: 0.981975
#
# Epoch 00008: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0454 - acc: 0.9830 - val_loss: 0.0453 - val_acc: 0.9833
# Epoch 9/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0448 - acc: 0.9831
#  ROC-AUC - epoch: 9 - score: 0.981099
#
# Epoch 00009: val_loss improved from 0.04501 to 0.04416, saving model to HAN_3_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0448 - acc: 0.9831 - val_loss: 0.0442 - val_acc: 0.9835
# Epoch 10/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0446 - acc: 0.9832
#  ROC-AUC - epoch: 10 - score: 0.980824
#
# Epoch 00010: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0446 - acc: 0.9832 - val_loss: 0.0452 - val_acc: 0.9835
# Epoch 11/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0437 - acc: 0.9834
#  ROC-AUC - epoch: 11 - score: 0.981574
#
# Epoch 00011: val_loss did not improve
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0437 - acc: 0.9834 - val_loss: 0.0442 - val_acc: 0.9836
# Epoch 12/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0435 - acc: 0.9835
#  ROC-AUC - epoch: 12 - score: 0.982299
#
# Epoch 00012: val_loss improved from 0.04416 to 0.04389, saving model to HAN_3_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0436 - acc: 0.9835 - val_loss: 0.0439 - val_acc: 0.9835
# Epoch 13/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0430 - acc: 0.9837
#  ROC-AUC - epoch: 13 - score: 0.981929
#
# Epoch 00013: val_loss did not improve
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0430 - acc: 0.9837 - val_loss: 0.0442 - val_acc: 0.9835
# Epoch 14/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0425 - acc: 0.9837
#  ROC-AUC - epoch: 14 - score: 0.981556
#
# Epoch 00014: val_loss did not improve
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0425 - acc: 0.9837 - val_loss: 0.0440 - val_acc: 0.9836
# Epoch 15/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0424 - acc: 0.9839
#  ROC-AUC - epoch: 15 - score: 0.981514
#
# Epoch 00015: val_loss did not improve
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0424 - acc: 0.9839 - val_loss: 0.0445 - val_acc: 0.9833
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0738 - acc: 0.9763
#  ROC-AUC - epoch: 1 - score: 0.975022
#
# Epoch 00001: val_loss improved from inf to 0.04961, saving model to HAN_4_.hdf5
# 143614/143614 [==============================] - 202s 1ms/step - loss: 0.0738 - acc: 0.9763 - val_loss: 0.0496 - val_acc: 0.9817
# Epoch 2/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0544 - acc: 0.9807
#  ROC-AUC - epoch: 2 - score: 0.978358
#
# Epoch 00002: val_loss improved from 0.04961 to 0.04767, saving model to HAN_4_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0544 - acc: 0.9807 - val_loss: 0.0477 - val_acc: 0.9822
# Epoch 3/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0516 - acc: 0.9812
#  ROC-AUC - epoch: 3 - score: 0.981112
#
# Epoch 00003: val_loss improved from 0.04767 to 0.04628, saving model to HAN_4_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0516 - acc: 0.9812 - val_loss: 0.0463 - val_acc: 0.9830
# Epoch 4/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0495 - acc: 0.9818
#  ROC-AUC - epoch: 4 - score: 0.983152
#
# Epoch 00004: val_loss improved from 0.04628 to 0.04432, saving model to HAN_4_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0495 - acc: 0.9818 - val_loss: 0.0443 - val_acc: 0.9833
# Epoch 5/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0483 - acc: 0.9820
#  ROC-AUC - epoch: 5 - score: 0.983815
#
# Epoch 00005: val_loss improved from 0.04432 to 0.04361, saving model to HAN_4_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0483 - acc: 0.9820 - val_loss: 0.0436 - val_acc: 0.9835
# Epoch 6/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0469 - acc: 0.9825
#  ROC-AUC - epoch: 6 - score: 0.984697
#
# Epoch 00006: val_loss improved from 0.04361 to 0.04331, saving model to HAN_4_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0469 - acc: 0.9825 - val_loss: 0.0433 - val_acc: 0.9837
# Epoch 7/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0461 - acc: 0.9827
#  ROC-AUC - epoch: 7 - score: 0.984396
#
# Epoch 00007: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0461 - acc: 0.9827 - val_loss: 0.0433 - val_acc: 0.9836
# Epoch 8/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0456 - acc: 0.9829
#  ROC-AUC - epoch: 8 - score: 0.985078
#
# Epoch 00008: val_loss improved from 0.04331 to 0.04289, saving model to HAN_4_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0456 - acc: 0.9829 - val_loss: 0.0429 - val_acc: 0.9842
# Epoch 9/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0451 - acc: 0.9831
#  ROC-AUC - epoch: 9 - score: 0.986423
#
# Epoch 00009: val_loss improved from 0.04289 to 0.04197, saving model to HAN_4_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0451 - acc: 0.9831 - val_loss: 0.0420 - val_acc: 0.9844
# Epoch 10/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0444 - acc: 0.9832
#  ROC-AUC - epoch: 10 - score: 0.985939
#
# Epoch 00010: val_loss did not improve
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0444 - acc: 0.9832 - val_loss: 0.0425 - val_acc: 0.9841
# Epoch 11/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0439 - acc: 0.9834
#  ROC-AUC - epoch: 11 - score: 0.986523
#
# Epoch 00011: val_loss did not improve
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0439 - acc: 0.9834 - val_loss: 0.0424 - val_acc: 0.9840
# Epoch 12/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0434 - acc: 0.9835
#  ROC-AUC - epoch: 12 - score: 0.986753
#
# Epoch 00012: val_loss improved from 0.04197 to 0.04192, saving model to HAN_4_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0434 - acc: 0.9835 - val_loss: 0.0419 - val_acc: 0.9840
# Epoch 13/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0430 - acc: 0.9837
#  ROC-AUC - epoch: 13 - score: 0.987319
#
# Epoch 00013: val_loss improved from 0.04192 to 0.04176, saving model to HAN_4_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0430 - acc: 0.9837 - val_loss: 0.0418 - val_acc: 0.9844
# Epoch 14/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0428 - acc: 0.9838
#  ROC-AUC - epoch: 14 - score: 0.987029
#
# Epoch 00014: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0428 - acc: 0.9838 - val_loss: 0.0418 - val_acc: 0.9844
# Epoch 15/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0423 - acc: 0.9839
#  ROC-AUC - epoch: 15 - score: 0.986979
#
# Epoch 00015: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0424 - acc: 0.9839 - val_loss: 0.0419 - val_acc: 0.9843
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0764 - acc: 0.9757
#  ROC-AUC - epoch: 1 - score: 0.974295
#
# Epoch 00001: val_loss improved from inf to 0.04844, saving model to HAN_5_.hdf5
# 143614/143614 [==============================] - 203s 1ms/step - loss: 0.0764 - acc: 0.9757 - val_loss: 0.0484 - val_acc: 0.9824
# Epoch 2/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0551 - acc: 0.9803
#  ROC-AUC - epoch: 2 - score: 0.976826
#
# Epoch 00002: val_loss improved from 0.04844 to 0.04800, saving model to HAN_5_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0551 - acc: 0.9803 - val_loss: 0.0480 - val_acc: 0.9825
# Epoch 3/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0520 - acc: 0.9810
#  ROC-AUC - epoch: 3 - score: 0.980374
#
# Epoch 00003: val_loss improved from 0.04800 to 0.04414, saving model to HAN_5_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0520 - acc: 0.9811 - val_loss: 0.0441 - val_acc: 0.9833
# Epoch 4/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0504 - acc: 0.9813
#  ROC-AUC - epoch: 4 - score: 0.982033
#
# Epoch 00004: val_loss improved from 0.04414 to 0.04272, saving model to HAN_5_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0503 - acc: 0.9813 - val_loss: 0.0427 - val_acc: 0.9839
# Epoch 5/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0486 - acc: 0.9819
#  ROC-AUC - epoch: 5 - score: 0.982931
#
# Epoch 00005: val_loss improved from 0.04272 to 0.04212, saving model to HAN_5_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0487 - acc: 0.9819 - val_loss: 0.0421 - val_acc: 0.9841
# Epoch 6/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0474 - acc: 0.9823
#  ROC-AUC - epoch: 6 - score: 0.984035
#
# Epoch 00006: val_loss improved from 0.04212 to 0.04117, saving model to HAN_5_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0474 - acc: 0.9823 - val_loss: 0.0412 - val_acc: 0.9843
# Epoch 7/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0468 - acc: 0.9823
#  ROC-AUC - epoch: 7 - score: 0.983930
#
# Epoch 00007: val_loss did not improve
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0468 - acc: 0.9823 - val_loss: 0.0413 - val_acc: 0.9842
# Epoch 8/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0461 - acc: 0.9826
#  ROC-AUC - epoch: 8 - score: 0.984649
#
# Epoch 00008: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0461 - acc: 0.9826 - val_loss: 0.0416 - val_acc: 0.9838
# Epoch 9/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0452 - acc: 0.9829
#  ROC-AUC - epoch: 9 - score: 0.984841
#
# Epoch 00009: val_loss improved from 0.04117 to 0.04115, saving model to HAN_5_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0452 - acc: 0.9829 - val_loss: 0.0412 - val_acc: 0.9845
# Epoch 10/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0449 - acc: 0.9831
#  ROC-AUC - epoch: 10 - score: 0.984955
#
# Epoch 00010: val_loss improved from 0.04115 to 0.04078, saving model to HAN_5_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0449 - acc: 0.9831 - val_loss: 0.0408 - val_acc: 0.9844
# Epoch 11/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0442 - acc: 0.9831
#  ROC-AUC - epoch: 11 - score: 0.985320
#
# Epoch 00011: val_loss improved from 0.04078 to 0.04078, saving model to HAN_5_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0442 - acc: 0.9831 - val_loss: 0.0408 - val_acc: 0.9845
# Epoch 12/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0437 - acc: 0.9833
#  ROC-AUC - epoch: 12 - score: 0.984578
#
# Epoch 00012: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0437 - acc: 0.9833 - val_loss: 0.0409 - val_acc: 0.9847
# Epoch 13/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0435 - acc: 0.9834
#  ROC-AUC - epoch: 13 - score: 0.985426
#
# Epoch 00013: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0435 - acc: 0.9834 - val_loss: 0.0415 - val_acc: 0.9838
# Epoch 14/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0431 - acc: 0.9835
#  ROC-AUC - epoch: 14 - score: 0.985052
#
# Epoch 00014: val_loss improved from 0.04078 to 0.04061, saving model to HAN_5_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0431 - acc: 0.9835 - val_loss: 0.0406 - val_acc: 0.9846
# Epoch 15/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0427 - acc: 0.9837
#  ROC-AUC - epoch: 15 - score: 0.985010
#
# Epoch 00015: val_loss did not improve
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0427 - acc: 0.9837 - val_loss: 0.0407 - val_acc: 0.9845
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0700 - acc: 0.9770
#  ROC-AUC - epoch: 1 - score: 0.972871
#
# Epoch 00001: val_loss improved from inf to 0.04785, saving model to HAN_6_.hdf5
# 143614/143614 [==============================] - 202s 1ms/step - loss: 0.0699 - acc: 0.9770 - val_loss: 0.0478 - val_acc: 0.9823
# Epoch 2/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0538 - acc: 0.9806
#  ROC-AUC - epoch: 2 - score: 0.978001
#
# Epoch 00002: val_loss improved from 0.04785 to 0.04606, saving model to HAN_6_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0538 - acc: 0.9806 - val_loss: 0.0461 - val_acc: 0.9828
# Epoch 3/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0507 - acc: 0.9815
#  ROC-AUC - epoch: 3 - score: 0.980657
#
# Epoch 00003: val_loss improved from 0.04606 to 0.04411, saving model to HAN_6_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0507 - acc: 0.9815 - val_loss: 0.0441 - val_acc: 0.9832
# Epoch 4/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0488 - acc: 0.9821
#  ROC-AUC - epoch: 4 - score: 0.981939
#
# Epoch 00004: val_loss improved from 0.04411 to 0.04372, saving model to HAN_6_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0488 - acc: 0.9821 - val_loss: 0.0437 - val_acc: 0.9835
# Epoch 5/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0477 - acc: 0.9823
#  ROC-AUC - epoch: 5 - score: 0.982743
#
# Epoch 00005: val_loss improved from 0.04372 to 0.04251, saving model to HAN_6_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0477 - acc: 0.9823 - val_loss: 0.0425 - val_acc: 0.9838
# Epoch 6/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0466 - acc: 0.9826
#  ROC-AUC - epoch: 6 - score: 0.983334
#
# Epoch 00006: val_loss improved from 0.04251 to 0.04193, saving model to HAN_6_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0466 - acc: 0.9826 - val_loss: 0.0419 - val_acc: 0.9839
# Epoch 7/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0456 - acc: 0.9828
#  ROC-AUC - epoch: 7 - score: 0.984480
#
# Epoch 00007: val_loss improved from 0.04193 to 0.04192, saving model to HAN_6_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0456 - acc: 0.9828 - val_loss: 0.0419 - val_acc: 0.9842
# Epoch 8/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0451 - acc: 0.9831
#  ROC-AUC - epoch: 8 - score: 0.984762
#
# Epoch 00008: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0451 - acc: 0.9831 - val_loss: 0.0421 - val_acc: 0.9836
# Epoch 9/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0446 - acc: 0.9832
#  ROC-AUC - epoch: 9 - score: 0.984995
#
# Epoch 00009: val_loss improved from 0.04192 to 0.04130, saving model to HAN_6_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0446 - acc: 0.9832 - val_loss: 0.0413 - val_acc: 0.9838
# Epoch 10/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0439 - acc: 0.9835
#  ROC-AUC - epoch: 10 - score: 0.984750
#
# Epoch 00010: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0439 - acc: 0.9835 - val_loss: 0.0425 - val_acc: 0.9834
# Epoch 11/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0434 - acc: 0.9835
#  ROC-AUC - epoch: 11 - score: 0.984738
#
# Epoch 00011: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0434 - acc: 0.9835 - val_loss: 0.0417 - val_acc: 0.9839
# Epoch 12/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0431 - acc: 0.9837
#  ROC-AUC - epoch: 12 - score: 0.985242
#
# Epoch 00012: val_loss did not improve
# 143614/143614 [==============================] - 199s 1ms/step - loss: 0.0431 - acc: 0.9837 - val_loss: 0.0420 - val_acc: 0.9833
# Epoch 13/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0428 - acc: 0.9839
#  ROC-AUC - epoch: 13 - score: 0.985209
#
# Epoch 00013: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0428 - acc: 0.9839 - val_loss: 0.0413 - val_acc: 0.9839
# Epoch 14/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0428 - acc: 0.9838
#  ROC-AUC - epoch: 14 - score: 0.985883
#
# Epoch 00014: val_loss did not improve
# 143614/143614 [==============================] - 199s 1ms/step - loss: 0.0428 - acc: 0.9838 - val_loss: 0.0420 - val_acc: 0.9837
# Epoch 15/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0422 - acc: 0.9839
#  ROC-AUC - epoch: 15 - score: 0.983979
#
# Epoch 00015: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0422 - acc: 0.9839 - val_loss: 0.0414 - val_acc: 0.9841
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0702 - acc: 0.9770
#  ROC-AUC - epoch: 1 - score: 0.973080
#
# Epoch 00001: val_loss improved from inf to 0.05024, saving model to HAN_7_.hdf5
# 143614/143614 [==============================] - 203s 1ms/step - loss: 0.0702 - acc: 0.9770 - val_loss: 0.0502 - val_acc: 0.9819
# Epoch 2/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0536 - acc: 0.9808
#  ROC-AUC - epoch: 2 - score: 0.978006
#
# Epoch 00002: val_loss improved from 0.05024 to 0.04745, saving model to HAN_7_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0536 - acc: 0.9808 - val_loss: 0.0475 - val_acc: 0.9823
# Epoch 3/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0508 - acc: 0.9815
#  ROC-AUC - epoch: 3 - score: 0.981569
#
# Epoch 00003: val_loss improved from 0.04745 to 0.04630, saving model to HAN_7_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0508 - acc: 0.9815 - val_loss: 0.0463 - val_acc: 0.9824
# Epoch 4/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0491 - acc: 0.9818
#  ROC-AUC - epoch: 4 - score: 0.982670
#
# Epoch 00004: val_loss improved from 0.04630 to 0.04516, saving model to HAN_7_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0491 - acc: 0.9818 - val_loss: 0.0452 - val_acc: 0.9828
# Epoch 5/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0476 - acc: 0.9822
#  ROC-AUC - epoch: 5 - score: 0.983162
#
# Epoch 00005: val_loss improved from 0.04516 to 0.04491, saving model to HAN_7_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0476 - acc: 0.9822 - val_loss: 0.0449 - val_acc: 0.9831
# Epoch 6/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0465 - acc: 0.9827
#  ROC-AUC - epoch: 6 - score: 0.983710
#
# Epoch 00006: val_loss improved from 0.04491 to 0.04398, saving model to HAN_7_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0465 - acc: 0.9827 - val_loss: 0.0440 - val_acc: 0.9831
# Epoch 7/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0456 - acc: 0.9830
#  ROC-AUC - epoch: 7 - score: 0.982892
#
# Epoch 00007: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0456 - acc: 0.9830 - val_loss: 0.0442 - val_acc: 0.9832
# Epoch 8/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0452 - acc: 0.9831
#  ROC-AUC - epoch: 8 - score: 0.983496
#
# Epoch 00008: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0452 - acc: 0.9831 - val_loss: 0.0442 - val_acc: 0.9836
# Epoch 9/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0446 - acc: 0.9832
#  ROC-AUC - epoch: 9 - score: 0.983106
#
# Epoch 00009: val_loss improved from 0.04398 to 0.04336, saving model to HAN_7_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0446 - acc: 0.9832 - val_loss: 0.0434 - val_acc: 0.9836
# Epoch 10/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0441 - acc: 0.9835
#  ROC-AUC - epoch: 10 - score: 0.984512
#
# Epoch 00010: val_loss improved from 0.04336 to 0.04293, saving model to HAN_7_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0441 - acc: 0.9835 - val_loss: 0.0429 - val_acc: 0.9838
# Epoch 11/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0435 - acc: 0.9836
#  ROC-AUC - epoch: 11 - score: 0.984076
#
# Epoch 00011: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0435 - acc: 0.9836 - val_loss: 0.0434 - val_acc: 0.9836
# Epoch 12/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0431 - acc: 0.9836
#  ROC-AUC - epoch: 12 - score: 0.984269
#
# Epoch 00012: val_loss improved from 0.04293 to 0.04292, saving model to HAN_7_.hdf5
# 143614/143614 [==============================] - 201s 1ms/step - loss: 0.0431 - acc: 0.9836 - val_loss: 0.0429 - val_acc: 0.9838
# Epoch 13/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0427 - acc: 0.9839
#  ROC-AUC - epoch: 13 - score: 0.984240
#
# Epoch 00013: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0428 - acc: 0.9839 - val_loss: 0.0432 - val_acc: 0.9835
# Epoch 14/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0426 - acc: 0.9837
#  ROC-AUC - epoch: 14 - score: 0.984090
#
# Epoch 00014: val_loss did not improve
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0426 - acc: 0.9837 - val_loss: 0.0430 - val_acc: 0.9833
# Epoch 15/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0422 - acc: 0.9839
#  ROC-AUC - epoch: 15 - score: 0.984954
#
# Epoch 00015: val_loss improved from 0.04292 to 0.04262, saving model to HAN_7_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0423 - acc: 0.9839 - val_loss: 0.0426 - val_acc: 0.9840
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0715 - acc: 0.9766
#  ROC-AUC - epoch: 1 - score: 0.973990
#
# Epoch 00001: val_loss improved from inf to 0.05309, saving model to HAN_8_.hdf5
# 143614/143614 [==============================] - 203s 1ms/step - loss: 0.0715 - acc: 0.9766 - val_loss: 0.0531 - val_acc: 0.9815
# Epoch 2/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0539 - acc: 0.9806
#  ROC-AUC - epoch: 2 - score: 0.980956
#
# Epoch 00002: val_loss improved from 0.05309 to 0.04656, saving model to HAN_8_.hdf5
# 143614/143614 [==============================] - 200s 1ms/step - loss: 0.0540 - acc: 0.9806 - val_loss: 0.0466 - val_acc: 0.9824
# Epoch 3/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0507 - acc: 0.9813
#  ROC-AUC - epoch: 3 - score: 0.983180
#
# Epoch 00003: val_loss improved from 0.04656 to 0.04420, saving model to HAN_8_.hdf5
# 143614/143614 [==============================] - 205s 1ms/step - loss: 0.0507 - acc: 0.9813 - val_loss: 0.0442 - val_acc: 0.9833
# Epoch 4/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0487 - acc: 0.9819
#  ROC-AUC - epoch: 4 - score: 0.984520
#
# Epoch 00004: val_loss improved from 0.04420 to 0.04383, saving model to HAN_8_.hdf5
# 143614/143614 [==============================] - 204s 1ms/step - loss: 0.0487 - acc: 0.9819 - val_loss: 0.0438 - val_acc: 0.9834
# Epoch 5/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0474 - acc: 0.9825
#  ROC-AUC - epoch: 5 - score: 0.984543
#
# Epoch 00005: val_loss improved from 0.04383 to 0.04333, saving model to HAN_8_.hdf5
# 143614/143614 [==============================] - 206s 1ms/step - loss: 0.0474 - acc: 0.9825 - val_loss: 0.0433 - val_acc: 0.9836
# Epoch 6/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0461 - acc: 0.9827
#  ROC-AUC - epoch: 6 - score: 0.985631
#
# Epoch 00006: val_loss improved from 0.04333 to 0.04193, saving model to HAN_8_.hdf5
# 143614/143614 [==============================] - 205s 1ms/step - loss: 0.0461 - acc: 0.9827 - val_loss: 0.0419 - val_acc: 0.9844
# Epoch 7/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0455 - acc: 0.9829
#  ROC-AUC - epoch: 7 - score: 0.986068
#
# Epoch 00007: val_loss did not improve
# 143614/143614 [==============================] - 205s 1ms/step - loss: 0.0455 - acc: 0.9829 - val_loss: 0.0420 - val_acc: 0.9843
# Epoch 8/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0450 - acc: 0.9829
#  ROC-AUC - epoch: 8 - score: 0.985996
#
# Epoch 00008: val_loss improved from 0.04193 to 0.04109, saving model to HAN_8_.hdf5
# 143614/143614 [==============================] - 207s 1ms/step - loss: 0.0450 - acc: 0.9829 - val_loss: 0.0411 - val_acc: 0.9844
# Epoch 9/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0445 - acc: 0.9833
#  ROC-AUC - epoch: 9 - score: 0.985830
#
# Epoch 00009: val_loss did not improve
# 143614/143614 [==============================] - 209s 1ms/step - loss: 0.0445 - acc: 0.9833 - val_loss: 0.0418 - val_acc: 0.9841
# Epoch 10/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0441 - acc: 0.9833
#  ROC-AUC - epoch: 10 - score: 0.986652
#
# Epoch 00010: val_loss improved from 0.04109 to 0.04084, saving model to HAN_8_.hdf5
# 143614/143614 [==============================] - 209s 1ms/step - loss: 0.0441 - acc: 0.9833 - val_loss: 0.0408 - val_acc: 0.9847
# Epoch 11/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0435 - acc: 0.9834
#  ROC-AUC - epoch: 11 - score: 0.985563
#
# Epoch 00011: val_loss did not improve
# 143614/143614 [==============================] - 208s 1ms/step - loss: 0.0435 - acc: 0.9834 - val_loss: 0.0430 - val_acc: 0.9838
# Epoch 12/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0429 - acc: 0.9836
#  ROC-AUC - epoch: 12 - score: 0.985995
#
# Epoch 00012: val_loss did not improve
# 143614/143614 [==============================] - 207s 1ms/step - loss: 0.0429 - acc: 0.9836 - val_loss: 0.0412 - val_acc: 0.9844
# Epoch 13/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0427 - acc: 0.9838
#  ROC-AUC - epoch: 13 - score: 0.986742
#
# Epoch 00013: val_loss improved from 0.04084 to 0.04074, saving model to HAN_8_.hdf5
# 143614/143614 [==============================] - 209s 1ms/step - loss: 0.0427 - acc: 0.9838 - val_loss: 0.0407 - val_acc: 0.9844
# Epoch 14/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0425 - acc: 0.9837
#  ROC-AUC - epoch: 14 - score: 0.986964
#
# Epoch 00014: val_loss improved from 0.04074 to 0.04070, saving model to HAN_8_.hdf5
# 143614/143614 [==============================] - 208s 1ms/step - loss: 0.0425 - acc: 0.9837 - val_loss: 0.0407 - val_acc: 0.9845
# Epoch 15/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0420 - acc: 0.9840
#  ROC-AUC - epoch: 15 - score: 0.987350
#
# Epoch 00015: val_loss did not improve
# 143614/143614 [==============================] - 208s 1ms/step - loss: 0.0420 - acc: 0.9840 - val_loss: 0.0422 - val_acc: 0.9840
# Train on 143614 samples, validate on 15957 samples
# Epoch 1/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0744 - acc: 0.9759
#  ROC-AUC - epoch: 1 - score: 0.970754
#
# Epoch 00001: val_loss improved from inf to 0.05250, saving model to HAN_9_.hdf5
# 143614/143614 [==============================] - 211s 1ms/step - loss: 0.0744 - acc: 0.9759 - val_loss: 0.0525 - val_acc: 0.9813
# Epoch 2/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0546 - acc: 0.9805
#  ROC-AUC - epoch: 2 - score: 0.972203
#
# Epoch 00002: val_loss improved from 0.05250 to 0.05031, saving model to HAN_9_.hdf5
# 143614/143614 [==============================] - 207s 1ms/step - loss: 0.0546 - acc: 0.9805 - val_loss: 0.0503 - val_acc: 0.9817
# Epoch 3/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0517 - acc: 0.9812
#  ROC-AUC - epoch: 3 - score: 0.976906
#
# Epoch 00003: val_loss improved from 0.05031 to 0.04854, saving model to HAN_9_.hdf5
# 143614/143614 [==============================] - 204s 1ms/step - loss: 0.0517 - acc: 0.9812 - val_loss: 0.0485 - val_acc: 0.9822
# Epoch 4/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0499 - acc: 0.9817
#  ROC-AUC - epoch: 4 - score: 0.978698
#
# Epoch 00004: val_loss improved from 0.04854 to 0.04649, saving model to HAN_9_.hdf5
# 143614/143614 [==============================] - 204s 1ms/step - loss: 0.0499 - acc: 0.9817 - val_loss: 0.0465 - val_acc: 0.9829
# Epoch 5/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0481 - acc: 0.9822
#  ROC-AUC - epoch: 5 - score: 0.979814
#
# Epoch 00005: val_loss did not improve
# 143614/143614 [==============================] - 204s 1ms/step - loss: 0.0481 - acc: 0.9822 - val_loss: 0.0473 - val_acc: 0.9828
# Epoch 6/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0471 - acc: 0.9824
#  ROC-AUC - epoch: 6 - score: 0.981517
#
# Epoch 00006: val_loss improved from 0.04649 to 0.04588, saving model to HAN_9_.hdf5
# 143614/143614 [==============================] - 205s 1ms/step - loss: 0.0471 - acc: 0.9824 - val_loss: 0.0459 - val_acc: 0.9827
# Epoch 7/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0461 - acc: 0.9827
#  ROC-AUC - epoch: 7 - score: 0.983337
#
# Epoch 00007: val_loss improved from 0.04588 to 0.04454, saving model to HAN_9_.hdf5
# 143614/143614 [==============================] - 202s 1ms/step - loss: 0.0461 - acc: 0.9827 - val_loss: 0.0445 - val_acc: 0.9833
# Epoch 8/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0454 - acc: 0.9830
#  ROC-AUC - epoch: 8 - score: 0.983644
#
# Epoch 00008: val_loss did not improve
# 143614/143614 [==============================] - 202s 1ms/step - loss: 0.0454 - acc: 0.9830 - val_loss: 0.0446 - val_acc: 0.9833
# Epoch 9/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0446 - acc: 0.9832
#  ROC-AUC - epoch: 9 - score: 0.984326
#
# Epoch 00009: val_loss improved from 0.04454 to 0.04424, saving model to HAN_9_.hdf5
# 143614/143614 [==============================] - 202s 1ms/step - loss: 0.0446 - acc: 0.9832 - val_loss: 0.0442 - val_acc: 0.9834
# Epoch 10/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0441 - acc: 0.9833
#  ROC-AUC - epoch: 10 - score: 0.984529
#
# Epoch 00010: val_loss improved from 0.04424 to 0.04404, saving model to HAN_9_.hdf5
# 143614/143614 [==============================] - 202s 1ms/step - loss: 0.0441 - acc: 0.9833 - val_loss: 0.0440 - val_acc: 0.9836
# Epoch 11/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0440 - acc: 0.9834
#  ROC-AUC - epoch: 11 - score: 0.983782
#
# Epoch 00011: val_loss improved from 0.04404 to 0.04371, saving model to HAN_9_.hdf5
# 143614/143614 [==============================] - 202s 1ms/step - loss: 0.0440 - acc: 0.9834 - val_loss: 0.0437 - val_acc: 0.9837
# Epoch 12/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0433 - acc: 0.9836
#  ROC-AUC - epoch: 12 - score: 0.984803
#
# Epoch 00012: val_loss improved from 0.04371 to 0.04334, saving model to HAN_9_.hdf5
# 143614/143614 [==============================] - 206s 1ms/step - loss: 0.0433 - acc: 0.9836 - val_loss: 0.0433 - val_acc: 0.9835
# Epoch 13/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0426 - acc: 0.9839
#  ROC-AUC - epoch: 13 - score: 0.983830
#
# Epoch 00013: val_loss did not improve
# 143614/143614 [==============================] - 204s 1ms/step - loss: 0.0426 - acc: 0.9839 - val_loss: 0.0445 - val_acc: 0.9837
# Epoch 14/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0428 - acc: 0.9837
#  ROC-AUC - epoch: 14 - score: 0.984625
#
# Epoch 00014: val_loss did not improve
# 143614/143614 [==============================] - 205s 1ms/step - loss: 0.0428 - acc: 0.9837 - val_loss: 0.0435 - val_acc: 0.9836
# Epoch 15/15
# 143552/143614 [============================>.] - ETA: 0s - loss: 0.0422 - acc: 0.9840
#  ROC-AUC - epoch: 15 - score: 0.984891
#
# Epoch 00015: val_loss did not improve
# 143614/143614 [==============================] - 207s 1ms/step - loss: 0.0422 - acc: 0.9840 - val_loss: 0.0438 - val_acc: 0.9839

# %%
list_of_preds = []
list_of_vals = []
list_of_y = []
fold_count = 10
fold_size = len(X) // 10
for fold_id in range(0, fold_count):
    fold_start = fold_size * fold_id
    fold_end = fold_start + fold_size

    if fold_id == 9:
        fold_end = len(X)

    X_valid = X[fold_start:fold_end]
    Y_valid = Y[fold_start:fold_end]
    X_train = np.concatenate([X[:fold_start], X[fold_end:]])
    Y_train = np.concatenate([Y[:fold_start], Y[fold_end:]])

    file_path = 'HAN_' + str(fold_id) + '_.hdf5'
    model = load_model(file_path) #,custom_objects = {"AttentionWeightedAverage": AttentionWeightedAverage}
    preds = model.predict(X_test, batch_size = 256, verbose = 1)
    list_of_preds.append(preds)
    vals = model.predict(X_valid, batch_size = 256, verbose = 1)
    list_of_vals.append(vals)
    list_of_y.append(Y_valid)
# Out:
# 153164/153164 [==============================] - 50s 327us/step
# 15957/15957 [==============================] - 5s 323us/step
# 153164/153164 [==============================] - 49s 323us/step
# 15957/15957 [==============================] - 5s 324us/step
# 153164/153164 [==============================] - 50s 327us/step
# 15957/15957 [==============================] - 5s 327us/step
# 153164/153164 [==============================] - 50s 330us/step
# 15957/15957 [==============================] - 5s 328us/step
# 153164/153164 [==============================] - 51s 331us/step
# 15957/15957 [==============================] - 5s 330us/step
# 153164/153164 [==============================] - 51s 333us/step
# 15957/15957 [==============================] - 5s 332us/step
# 153164/153164 [==============================] - 51s 335us/step
# 15957/15957 [==============================] - 5s 333us/step
# 153164/153164 [==============================] - 51s 335us/step
# 15957/15957 [==============================] - 5s 334us/step
# 153164/153164 [==============================] - 52s 338us/step
# 15957/15957 [==============================] - 5s 336us/step
# 153164/153164 [==============================] - 52s 338us/step
# 15958/15958 [==============================] - 5s 335us/step

# %%
test_predicts = np.zeros(list_of_preds[0].shape)
for fold_predict in list_of_preds:
    test_predicts += fold_predict

test_predicts /= len(list_of_preds)
submission = pd.read_csv('assets/raw_data/sample_submission.csv')
submission[LIST_CLASSES] = test_predicts
submission.to_csv('han_l2_test_data.csv', index=False)

l2_data = pd.DataFrame(columns=['logits_' + c for c in LIST_CLASSES]+LIST_CLASSES)
l2_data[['logits_' + c for c in LIST_CLASSES]] = pd.DataFrame(np.concatenate(list_of_vals,axis = 0))
l2_data[LIST_CLASSES] = pd.DataFrame(np.concatenate(list_of_y,axis = 0))
l2_data.to_csv('han_l2_train_data.csv')
